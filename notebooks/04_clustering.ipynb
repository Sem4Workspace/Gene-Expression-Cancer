# %% [markdown]
# # Phase 4 -- Unsupervised Clustering
#
# ## Objective
#
# Discover natural groupings in the gene expression data without using class labels. We apply K-Means clustering on SVD-reduced features to test whether tumor samples self-organize into biologically meaningful clusters.
#
# ### Method
#
# - **Input:** First 2 SVD components (from the U matrix)
# - **Algorithm:** K-Means clustering
# - **Cluster selection:** Elbow method and silhouette analysis
# - **Validation:** Visual inspection in 2D SVD space

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.linear_algebra.svd_core import compute_truncated_svd
from src.ml.clustering import run_kmeans, compute_silhouette
from src.visualization.clustering_plots import plot_clusters_2d

# %%
X = pd.read_csv(r"../Data/processed/X_processed.csv").values

# %%
U_reduced, singular_values, svd_model = compute_truncated_svd(
    X,
    n_components=10
)

# %% [markdown]
# ## 4.1 Elbow Method -- Selecting Optimal k
#
# The elbow method plots within-cluster inertia (sum of squared distances to centroids) against the number of clusters. The "elbow" point where inertia begins to decrease more slowly suggests an appropriate number of clusters.

# %%
inertias = []
k_values = range(2, 11)

for k in k_values:
    _, model = run_kmeans(U_reduced[:, :2], k)
    inertias.append(model.inertia_)

plt.figure(figsize=(6,4))
plt.plot(k_values, inertias, marker="o")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.2 Silhouette Analysis
#
# The silhouette score measures how similar a sample is to its own cluster compared to the nearest neighboring cluster. Values range from -1 to +1, where higher scores indicate better-defined clusters. We evaluate silhouette scores for k = 2 through 10.

# %%
silhouette_scores = []

for k in k_values:
    labels, _ = run_kmeans(U_reduced[:, :2], k)
    score = compute_silhouette(U_reduced[:, :2], labels)
    silhouette_scores.append(score)

plt.figure(figsize=(6,4))
plt.plot(k_values, silhouette_scores, marker="o")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.3 K-Means Clustering (k = 3)
#
# Based on the elbow and silhouette analysis, we select k = 3 and perform final K-Means clustering on the first two SVD components. The resulting clusters are visualized in the 2D SVD projection space.

# %%
k_optimal = 3

cluster_labels, kmeans_model = run_kmeans(
    U_reduced[:, :2],
    n_clusters=k_optimal
)

# %%
plot_clusters_2d(
    U_reduced[:, :2],
    cluster_labels,
    save_path="../results/figures/kmeans_clusters_svd.png"
)

# %% [markdown]
# ## 4.4 Save Cluster Assignments
#
# Cluster assignments are saved to `results/tables/cluster_assignments.csv` for downstream comparison with the true cancer type labels.

# %%
cluster_df = pd.DataFrame({
    "sample_index": range(len(cluster_labels)),
    "cluster": cluster_labels
})

cluster_df.to_csv(
    "../results/tables/cluster_assignments.csv",
    index=False
)

cluster_df.head()
# Out:
#    sample_index  cluster
# 0             0        0
# 1             1        0
# 2             2        0
# 3             3        0
# 4             4        2
